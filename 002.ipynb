# %%
print("Hello HDI!")

caixinha = "Juliana" # Tipo string
idade = 33 # Integer
tipoErrado = "2"

resultadoIdade = idade+idade
resultadoErrado = tipoErrado+tipoErrado

print(caixinha)

print("--------SOMA DE INTEIROs--------")
print(resultadoIdade)
print("--------SOMA DE STRINGs--------")
print(resultadoErrado) # Concatenou 


convertido = str(idade)
print("A idade da " + caixinha + " é " + str(idade))

anoAtual = int(input("Em que ano estamos?"))
anoNasc = int(input("Em que ano você nasceu?"))

resultado = anoAtual - anoNasc
# Out:
# Hello HDI!
# Juliana
# --------SOMA DE INTEIROs--------
# 66
# --------SOMA DE STRINGs--------
# 22
# A idade da Juliana é 33
