# %%
def minhaFuncao():
    print("-----------------------------------------------")
    print("------------JULIANA BURGO ARVANI---------------")
    print("-----------------------------------------------")

minhaFuncao()
minhaFuncao()
minhaFuncao()

cidades = ['São Paulo', 'Rio de Janeiro', 'Poá', 'Belo Horizonte', 'Tapiratiba', 'Recife']
contador = 0

def minhaFuncaoMelhorada(x, cidade):
    print(str(x) + ' - ' + cidade)

for cidade in cidades:
    contador = contador+1
    minhaFuncaoMelhorada(contador, cidade)
# Out:
# -----------------------------------------------
# ------------JULIANA BURGO ARVANI---------------
# -----------------------------------------------
# -----------------------------------------------
# ------------JULIANA BURGO ARVANI---------------
# -----------------------------------------------
# -----------------------------------------------
# ------------JULIANA BURGO ARVANI---------------
# -----------------------------------------------
# 1 - São Paulo
# 2 - Rio de Janeiro
# 3 - Poá
# 4 - Belo Horizonte
# 5 - Tapiratiba
# 6 - Recife

# %%
contador = 0
for cidade in cidades:
    for letra in cidade:
        print(str(contador) + ' - ' + letra)
        contador=contador+1
# Out:
# 0 - S
# 1 - ã
# 2 - o
# 3 -
# 4 - P
# 5 - a
# 6 - u
# 7 - l
# 8 - o
# 9 - R
# 10 - i
# 11 - o
# 12 -
# 13 - d
# 14 - e
# 15 -
# 16 - J
# 17 - a
# 18 - n
# 19 - e
# 20 - i
# 21 - r
# 22 - o
# 23 - P
# 24 - o
# 25 - á
# 26 - B
# 27 - e
# 28 - l
# 29 - o
# 30 -
# 31 - H
# 32 - o
# 33 - r
# 34 - i
# 35 - z
# 36 - o
# 37 - n
# 38 - t
# 39 - e
# 40 - T
# 41 - a
# 42 - p
# 43 - i
# 44 - r
# 45 - a
# 46 - t
# 47 - i
# 48 - b
# 49 - a
# 50 - R
# 51 - e
# 52 - c
# 53 - i
# 54 - f
# 55 - e
